# %% [markdown]
# # Mira con quién andas

# %%
from similarly import *
top10 = tops()

# %%
from IPython.display import HTML
html = '<TABLE><TR><TH>Base</TH><TH>Vecinos</TH></TR>'
for filename, file_info, doc_data in top10:
    html += '<TR><TD>%s %s</TD>' %(filename, file_info)
    html += '<TD><TABLE>'
    for dd in doc_data:
        html+= '<TR><TD>%s</TD><TD>%s</TD><TD>%s</TD><TD>%s</TD></TR>' %(dd[0][0],dd[0][1],dd[1],dd[2])
    html += '</TABLE></TD></TR>'

html += '</TABLE>'
HTML(html)
# Out:
# <TABLE><TR><TH>Base</TH><TH>Vecinos</TH></TR><TR><TD>(0, 'D10_ALEJANDRA_DEL_PILAR_JIMENEZ_CASTRO.txt') ['PARTIDO COMUNISTA DE CHILE' 'APRUEBO DIGNIDAD']</TD><TD><TABLE><TR><TD>587</TD><TD>D22_PABLO_ANDRES_TAPIA_PINTO.txt</TD><TD>['INDEPENDIENTES' 'MOVIMIENTO SOCIAL LA LISTA DEL PUEBLO (D22)']</TD><TD>0.889</TD></TR><TR><TD>507</TD><TD>D20_MARIA_CONSUELO_MOLINA_RODRIGUEZ.txt</TD><TD>['INDEPENDIENTES' 'LA LISTA DEL PUEBLO(D20)']</TD><TD>0.888</TD></TR><TR><TD>586</TD><TD>D22_OSCAR_JAVIER_SALAZAR_ASTUDILLO.txt</TD><TD>['INDEPENDIENTES' 'MOVIMIENTO SOCIAL LA LISTA DEL PUEBLO (D22)']</TD><TD>0.887</TD></TR><TR><TD>643</TD><TD>D23_ROSSANA_ANGELICA_BETANCUR_ESCOBAR.txt</TD><TD>['INDEPENDIENTES' 'ELIGE LA LISTA DEL PUEBLO (D23)']</TD><TD>0.887</TD></TR><TR><TD>1137</TD><TD>D9_BARBARA_SEPULVEDA_HALES.txt</TD><TD>['PARTIDO COMUNISTA DE CHILE' 'APRUEBO DIGNIDAD']</TD><TD>0.887</TD></TR><TR><TD>616</TD><TD>D23_HELMUTH_JACOBO_MARTINEZ_LLANCAPAN.txt</TD><TD>['INDEPENDIENTES' 'ELIGE LA LISTA DEL PU
# ...

# %%
print(top10[0][0])
print(top10[0][1])
# Out:
# (0, 'D10_ALEJANDRA_DEL_PILAR_JIMENEZ_CASTRO.txt')
# ['PARTIDO COMUNISTA DE CHILE' 'APRUEBO DIGNIDAD']

# %%
print(doc_data[0])
# Out:
# ((587, 'D22_PABLO_ANDRES_TAPIA_PINTO.txt'), array(['INDEPENDIENTES', 'MOVIMIENTO SOCIAL LA LISTA DEL PUEBLO (D22)'],
#       dtype=object), 0.889)

# %%
top10[0]
# Out:
# [(0, 'D10_ALEJANDRA_DEL_PILAR_JIMENEZ_CASTRO.txt'),
#  array(['PARTIDO COMUNISTA DE CHILE', 'APRUEBO DIGNIDAD'], dtype=object),
#  [((587, 'D22_PABLO_ANDRES_TAPIA_PINTO.txt'),
#    array(['INDEPENDIENTES', 'MOVIMIENTO SOCIAL LA LISTA DEL PUEBLO (D22)'],
#          dtype=object),
#    0.889),
#   ((507, 'D20_MARIA_CONSUELO_MOLINA_RODRIGUEZ.txt'),
#    array(['INDEPENDIENTES', 'LA LISTA DEL PUEBLO(D20)'], dtype=object),
#    0.888),
#   ((586, 'D22_OSCAR_JAVIER_SALAZAR_ASTUDILLO.txt'),
#    array(['INDEPENDIENTES', 'MOVIMIENTO SOCIAL LA LISTA DEL PUEBLO (D22)'],
#          dtype=object),
#    0.887),
#   ((643, 'D23_ROSSANA_ANGELICA_BETANCUR_ESCOBAR.txt'),
#    array(['INDEPENDIENTES', 'ELIGE LA LISTA DEL PUEBLO (D23)'], dtype=object),
#    0.887),
#   ((1137, 'D9_BARBARA_SEPULVEDA_HALES.txt'),
#    array(['PARTIDO COMUNISTA DE CHILE', 'APRUEBO DIGNIDAD'], dtype=object),
#    0.887),
#   ((616, 'D23_HELMUTH_JACOBO_MARTINEZ_LLANCAPAN.txt'),
# ...
