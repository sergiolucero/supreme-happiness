# %%
import pandas as pd
t1=open('TEXTOS/TODOS/D10_ALEXIS_CRISTOPHER_GARRIDO_NUÑEZ.txt').read()
#t2=open('TEXTOS/TODOS/D13_VALERIA_ALEJANDRA_VILLEGAS_MAYOR.txt').read()
t2=chr(10).join([open('TEXTOS/TODOS/D6_CORINA_DEL_PILAR_SILVA_FIGUEROA.txt').read()])

# %%
from IPython.display import HTML
N=3000
html = '<TABLE><TR><TD>%s</TD><TD>%s</TD></TR></TABLE>'  %(t1[:N],t2[:N])
HTML(html)
# Out:
# <TABLE><TR><TD>(' \n'
#  'Por un Estado Constitucional Ambiental, Igualitario y Participativo \n'
#  ' \n'
#  'Esta Propuesta al País tiene como propósito transformar el Poder del '
#  'Movimiento Social en Poder \n'
#  'Electoral Constituyente. Busca favorecer que sean elegidos como '
#  'convencionales constituyentes \n'
#  'personas y representantes de organizaciones de la sociedad civil que han '
#  'venido impulsando la demanda \n'
#  'por una nueva Constitución y han demostrado su compromiso con las '
#  'reivindicaciones y la causa del \n'
#  'Pueblo. \n'
#  'Pensamos que se requiere la construcción de un sólido aparato institucional '
#  'que reconozca los derechos \n'
#  'sociales, económicos y culturales y lidere, con colaboración privada en '
#  'algunos casos, la solución de los \n'
#  'graves problemas de pobreza y exclusión que ha enfrentado nuestro país desde '
#  'sus orígenes y que serán \n'
#  'profundizados dramáticamente por el cambio climático y la revolución '
# ...

# %%
t1=open('TEXTOS/TODOS/D10_CARMEN_VERONICA_CONTRERAS_AROS.txt').read()
t2=open('TEXTOS/TODOS/D23_GUISELA_CAROLINA_OLATE_SANCHEZ.txt').read()
html = '<TABLE><TR><TD>%s</TD><TD>%s</TD></TR></TABLE>'  %(t1[:N],t2[:N])
HTML(html)
# Out:
# <TABLE><TR><TD>(' Temas para debatir en Relación a una  nueva Constitución \n'
#  ' \n'
#  '1- La validez delas normas de facto  \n'
#  '2- El constitucionalismo como prisión de la democracia   \n'
#  '3- Reelecciones de los cargos  \n'
#  '4- Procedimiento de creación constitucional  \n'
#  '5- Derechos: \n'
#  '6- Organización del poder  \n'
#  '7- Democracia  \n'
#  '8- Sociología y política  \n'
#  '9- Filosofía publica \n'
#  '10- Constitucionalismo  democrático en Chile  \n'
#  ' \n'
#  ' \n'
#  ' \n'
#  ' \n'
#  'CARMEN VERONICA CONTRERAS AROS \n'
#  ' \n')
# </TD><TD>('PROGRAMA CONVENCION CONSTITUCIONAL \n'
#  ' \n'
#  'CONSERVAR LO BUENO, CAMBIAR LO MALO Y AGREGAR PEQUEÑOS CAMBIOS, DE '
#  'POSITIVISMO \n'
#  'CIUDADANO. \n')
# </TD></TR></TABLE>

# %%
from similarly import *
top10 = tops()
def tload(top10x):
    t1, t2 = top10x[0][1], top10x[2][0][0][1]
    t1, t2 = [open('TEXTOS/TODOS/'+tx).read() for tx in (t1,t2)]
    html = '<TABLE><TR><TD>%s</TD><TD>%s</TD></TR></TABLE>'  %(t1[:N],t2[:N])
    return HTML(html)

# %%
tload(top10[6])
# Out:
# <TABLE><TR><TD>(' \n'
#  'PROGRAMA CANDIDATURA INDEPENDIENTE DE CAMILO PARADA \n'
#  'ORTIZ (DISTRITO 10) PARA LA CONVENCIÓN CONSTITUCIONAL \n'
#  ' \n'
#  ' \n'
#  ' \n'
#  '1. Por soberanía constituyente: La Convención debe ser un órgano soberano, '
#  'en \n'
#  'donde se pueda discutir todas las temáticas necesarias para tener una '
#  'Carta \n'
#  'Magna que dispongan las mayorías sociales, sin vetos, sin condiciones. \n'
#  'Promovemos establecer la soberanía popular en la Convención '
#  'Constitucional, \n'
#  'impulsando una Asamblea Constituyente libre, soberana, plurinacional y \n'
#  'democrática. \n'
#  ' \n'
#  '2. Por un Chile ecologista: Nacionalización y estatización de nuestros '
#  'bienes \n'
#  'comunes, comenzando por el agua. Reconversión productiva de las industrias \n'
#  'contaminantes y laboral/profesional de sus trabajadores y trabajadoras con \n'
#  'garantía de continuidad salarial por parte del Estado. Plan de transición, '
#  'bajo \n'
# ...
