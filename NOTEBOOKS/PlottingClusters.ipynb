# %% [markdown]
# # Reload and cluster plot

# %%
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

modelos = pickle.load(open('modelos.pk', 'rb'))
#modelos = {'kmeans': (kmeans_model, labels, clusters),
#            'pca': (pca, datapoint), 'd2v': d2v_model}

kmeans_model, labels, clusters = modelos['kmeans']
pca, datapoint = modelos['pca']
d2v_model = modelos['d2v']

fig, ax = plt.subplots(1, figsize=(20,12))
ax.set_facecolor('xkcd:baby blue')
label1 = ["#FFFF00", "#008000", "#0000FF", "#800080"]
color = [label1[i] for i in labels]
plt.scatter(datapoint[:, 0], datapoint[:, 1], c=color)

centroids = kmeans_model.cluster_centers_
centroidpoint = pca.transform(centroids)
plt.scatter(centroidpoint[:, 0], centroidpoint[:, 1], marker='*', s=150, c='#ffffff')
plt.savefig('cluster1.png')
plt.show()

# %%
import pandas as pd

fig, ax = plt.subplots(1, figsize=(20,12))

sdf = pd.DataFrame(dict(x=datapoint[:, 0], y=datapoint[:, 1], c=color))
sns.scatterplot(data=sdf, x='x', y='y', color='c')
#plt.scatter(centroidpoint[:, 0], centroidpoint[:, 1], marker='*', s=150, c='#ffff12')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>
